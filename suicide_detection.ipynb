# %%
# install import necessary libraries

import pandas as pd

# for removing contractions
# !pip install contractions

# Used for removing stopwords and lemmatizing
# !pip install nltk

# Used for spell check
# !pip install pyenchant
# !apt update
# !apt install enchant --fix-missing
# !apt install -qq enchant


# Import the Sucide_Detctection.csv from google drive
from google.colab import drive
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 13.3 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 2.2 MB/s eta 0:00:00
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# ...

# %% [markdown]
# - Keep the orginal text and add a new column for clean text
# - lower case
# - spell check
# - stop words (changethe words to exclude to not be contractions)
# - print the stop word to check for any negation
# - contractions
# - dont export as csv
# - remove accented character

# %%
# Mount the google drive to collab
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read the Suicide_Detection.csv to a dataframe

df = pd.read_csv('/content/drive/MyDrive/Suicide_Detection.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0                                               text        class
# 0           2  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1           3  Am I weird I don't get affected by compliments...  non-suicide
# 2           4  Finally 2020 is almost over... So I can never ...  non-suicide
# 3           8          i need helpjust help me im crying so hard      suicide
# 4           9  I’m so lostHello, my name is Adam (16) and I’v...      suicide
# 5          11  Honetly idkI dont know what im even doing here...      suicide
# 6          12  [Trigger warning] Excuse for self inflicted bu...      suicide
# 7          13   It ends tonight.I can’t do it anymore. \nI quit.      suicide
# 8          16  Everyone wants to be "edgy" and it's making me...  non-suicide
# 9          18  My life is over at 20 years oldHello all. I am...      suicide

# %%
# convert the data in text column to lower case

df['clean_text'] = df['text'].str.lower()
df.head(10)
# Out:
#    Unnamed: 0                                               text        class  \
# 0           2  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1           3  Am I weird I don't get affected by compliments...  non-suicide
# 2           4  Finally 2020 is almost over... So I can never ...  non-suicide
# 3           8          i need helpjust help me im crying so hard      suicide
# 4           9  I’m so lostHello, my name is Adam (16) and I’v...      suicide
# 5          11  Honetly idkI dont know what im even doing here...      suicide
# 6          12  [Trigger warning] Excuse for self inflicted bu...      suicide
# 7          13   It ends tonight.I can’t do it anymore. \nI quit.      suicide
# 8          16  Everyone wants to be "edgy" and it's making me...  non-suicide
# 9          18  My life is over at 20 years oldHello all. I am...      suicide
#
#                                           clean_text
# 0  ex wife threatening suiciderecently i left my ...
# ...

# %%
# remove accented characters

import unicodedata
df["clean_text"].apply(lambda x: ''.join((c for c in unicodedata.normalize('NFD', x) if unicodedata.category(c) != 'Mn')))
df.head(10)
# Out:
#    Unnamed: 0                                               text        class  \
# 0           2  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1           3  Am I weird I don't get affected by compliments...  non-suicide
# 2           4  Finally 2020 is almost over... So I can never ...  non-suicide
# 3           8          i need helpjust help me im crying so hard      suicide
# 4           9  I’m so lostHello, my name is Adam (16) and I’v...      suicide
# 5          11  Honetly idkI dont know what im even doing here...      suicide
# 6          12  [Trigger warning] Excuse for self inflicted bu...      suicide
# 7          13   It ends tonight.I can’t do it anymore. \nI quit.      suicide
# 8          16  Everyone wants to be "edgy" and it's making me...  non-suicide
# 9          18  My life is over at 20 years oldHello all. I am...      suicide
#
#                                           clean_text
# 0  ex wife threatening suiciderecently i left my ...
# ...

# %%
# Fix spelling issues. Use Multiprocessing to parallelize. NOT WORKING

# import enchant
# import numpy as np
# from multiprocessing import Pool

# # Performing spell check using enchant
# def spell_check_text(text):
#     corrected_text = []
#     words = text.split()

#     for word in words:
#         if enchant.Dict("en_US").check(word):
#             corrected_text.append(word)
#         else:
#             suggested_words = enchant.Dict("en_US").suggest(word)
#             if len(suggested_words) > 0:
#                 corrected_word = suggested_words[0]
#                 corrected_text.append(corrected_word)
#             else:
#                 corrected_text.append(word)
#     return ' '.join(corrected_text)

# # Function to parallelize the spell check
# def parallel_spell_check(text):
#     return text.apply(spell_check_text)

# # Number of processes for parallel execution
# num_processes = 4

# # Split the DataFrame into chunks for parallel processing
# chunks = np.array_split(df['clean_text'], num_processes)

# # Create a multiprocessing Pool
# pool = Pool(processes=num_processes)

# # Apply spell check in parallel using multiple processes
# result_chunks = pool.map(parallel_spell_check, chunks)

# # Concatenate the results into a single DataFrame
# df['clean_text'] = pd.concat(result_chunks)

# # Print the updated DataFrame
# df.head(10)

# %%
# remove stop words from the column 'text' in the data frame. Takes approx 5 mins


import nltk
from nltk.corpus import stopwords
import pandas as pd

# Download stop words
nltk.download('stopwords')
nltk.download('punkt')

# set english as language
stop_words = set(stopwords.words('english'))



# Add additional words to exclude from stop words since sentiments are important
words_to_exclude = {"wouldn't", "couldn't", "haven't",'mustn', "wasn't" , "hasn't", "weren't", 'wasn',
                    "doesn't", "mightn't", "shan't", "shouldn't", 'wouldn', 'couldn', "won't", 'never',
                    "didn't", 'no', 'do not', 'could not', 'cannot', 'will not', 'would not' }



# Exclude words from stop words
custom_stop_words = stop_words - set(words_to_exclude)
print(len(custom_stop_words))
print(custom_stop_words)

# Tokenize and remove stop words for each row in 'text' column
df['clean_text'] = df['clean_text'].apply(lambda x: ' '.join([word for word in nltk.word_tokenize(x) if word not in custom_stop_words]))

df.head(10)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 162
# ...

# %%
#removing contractions

import contractions
df['clean_text'] = df['clean_text'].apply(lambda x: contractions.fix(x))
df.head()
# Out:
#    Unnamed: 0                                               text        class  \
# 0           2  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1           3  Am I weird I don't get affected by compliments...  non-suicide
# 2           4  Finally 2020 is almost over... So I can never ...  non-suicide
# 3           8          i need helpjust help me im crying so hard      suicide
# 4           9  I’m so lostHello, my name is Adam (16) and I’v...      suicide
#
#                                           clean_text
# 0  ex wife threatening suiciderecently left wife ...
# 1  weird n't get affected compliments 's coming s...
# 2  finally 2020 almost ... never hear `` 2020 bad...
# 3                need helpjust help i am crying hard
# 4  ’ losthello , name adam ( 16 ) ’ struggling ye...

# %%
# removing punctuations, [^\w\s] removes any character that is not a word character like
# (letters, digits, and underscore) or whitespace.

import re
df['clean_text'] = df['clean_text'].str.replace(r'[^\w\s]', ' ', regex=True)
df.head(10)
# Out:
#    Unnamed: 0                                               text        class  \
# 0           2  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1           3  Am I weird I don't get affected by compliments...  non-suicide
# 2           4  Finally 2020 is almost over... So I can never ...  non-suicide
# 3           8          i need helpjust help me im crying so hard      suicide
# 4           9  I’m so lostHello, my name is Adam (16) and I’v...      suicide
# 5          11  Honetly idkI dont know what im even doing here...      suicide
# 6          12  [Trigger warning] Excuse for self inflicted bu...      suicide
# 7          13   It ends tonight.I can’t do it anymore. \nI quit.      suicide
# 8          16  Everyone wants to be "edgy" and it's making me...  non-suicide
# 9          18  My life is over at 20 years oldHello all. I am...      suicide
#
#                                           clean_text
# 0  ex wife threatening suiciderecently left wife ...
# ...

# %%
# Lemmatize the words in 'clean_text' column. Takes ~6 mins

from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')  # Download WordNet data

lemmatizer = WordNetLemmatizer()

# Function to lemmatize a sentence
def lemmatize(text):
    tokens = nltk.word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(lemmatized_tokens)

# Lemmatize the 'text' column
df['clean_text'] = df['clean_text'].apply(lemmatize)

df.head(10)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#    Unnamed: 0                                               text        class  \
# 0           2  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1           3  Am I weird I don't get affected by compliments...  non-suicide
# 2           4  Finally 2020 is almost over... So I can never ...  non-suicide
# 3           8          i need helpjust help me im crying so hard      suicide
# 4           9  I’m so lostHello, my name is Adam (16) and I’v...      suicide
# 5          11  Honetly idkI dont know what im even doing here...      suicide
# 6          12  [Trigger warning] Excuse for self inflicted bu...      suicide
# 7          13   It ends tonight.I can’t do it anymore. \nI quit.      suicide
# 8          16  Everyone wants to be "edgy" and it's making me...  non-suicide
# 9          18  My life is over at 20 years oldHello all. I am...      suicide
#
# ...

# %%
#Find the frequency distribution for all words in the ENTIRE DOCUMENT in column 'clean_text'
from nltk import FreqDist
from nltk.tokenize import word_tokenize


# Merge all the values in the text column to one
all_text = ' '.join(df['clean_text'])

# compute the frequency dist of words
words = word_tokenize(all_text)
word_frequency = FreqDist(words)

# Convert the frequency distribution to a DataFrame and sort
frequency_df = pd.DataFrame.from_dict(word_frequency, orient='index', columns=['Frequency'])
frequency_df = frequency_df.sort_values('Frequency', ascending=False)


frequency_df.head(10)
# Out:
#       Frequency
# n        321922
# t        321092
# m        222242
# like     185130
# want     159051
# s        153345
# know     148320
# feel     136766
# life     129389
# get      120731

# %%
#Parts Of Speech tagging POSTag. Create a separate column called pos_tags . Took approx 17m

nltk.download('averaged_perceptron_tagger')

def parts_of_speech_tagging(text):
  tokens = nltk.word_tokenize(text)
  pos_tags = nltk.pos_tag(tokens)
  return pos_tags

# Perform POS tagging on the 'text' column
df['pos_tags'] = df['clean_text'].apply(parts_of_speech_tagging)
df.head(10)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
#    Unnamed: 0                                               text        class  \
# 0           2  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1           3  Am I weird I don't get affected by compliments...  non-suicide
# 2           4  Finally 2020 is almost over... So I can never ...  non-suicide
# 3           8          i need helpjust help me im crying so hard      suicide
# 4           9  I’m so lostHello, my name is Adam (16) and I’v...      suicide
# 5          11  Honetly idkI dont know what im even doing here...      suicide
# 6          12  [Trigger warning] Excuse for self inflicted bu...      suicide
# 7          13   It ends tonight.I can’t do it anymore. \nI quit.      suicide
# 8          16  Everyone wants to be "edgy" and it's making me...  non-suicide
# ...

# %%
# Perform Chunking and chinking to extract noun phrases and verb phrases, exlclude conjunctions and prepositions
# and add the chunk_chink column to dataframe

from nltk import Tree

def chunk_chink(pos_tags):
 # This grammar extracts noun phrases and verb phrases, exclude conjunctions and prepositions
  chunk_grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>}
    VP: {<RB.?>*<VB.*><RB.?>*}
    }<CC|IN>{
    """
  parser = nltk.RegexpParser(chunk_grammar)
  result = parser.parse(pos_tags)
  return result

df['chunk_chink'] = df['pos_tags'].apply(chunk_chink)
df.head(10)
# Out:
# ...
#    Unnamed: 0                                               text        class  \
# 0           2  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1           3  Am I weird I don't get affected by compliments...  non-suicide
# 2           4  Finally 2020 is almost over... So I can never ...  non-suicide
# 3           8          i need helpjust help me im crying so hard      suicide
# 4           9  I’m so lostHello, my name is Adam (16) and I’v...      suicide
# 5          11  Honetly idkI dont know what im even doing here...      suicide
# 6          12  [Trigger warning] Excuse for self inflicted bu...      suicide
# 7          13   It ends tonight.I can’t do it anymore. \nI quit.      suicide
# 8          16  Everyone wants to be "edgy" and it's making me...  non-suicide
# 9          18  My life is over at 20 years oldHello all. I am...      suicide
#
#                                           clean_text  \
# 0  ex wife threatening suiciderecently left wife ...
# ...

# %%
# export the dataframe as a pickle file

# Write DataFrame to a pickle file
df.to_pickle('/content/drive/MyDrive/Suicide_Detection.pickle')
